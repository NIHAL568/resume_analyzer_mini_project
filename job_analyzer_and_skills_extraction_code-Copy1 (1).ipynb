# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("UpdatedResumeDataSet.csv")
df.head()
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %%
df.shape
# Out:
# (962, 2)

# %%
df["Category"].value_counts()
# Out:
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# Blockchain                   40
# ETL Developer                40
# Operations Manager           40
# Data Science                 40
# Sales                        40
# Mechanical Engineer          40
# Arts                         36
# Database                     33
# Electrical Engineering       30
# Health and fitness           30
# PMO                          30
# Business Analyst             28
# DotNet Developer             28
# Automation Testing           26
# Network Security Engineer    25
# SAP Developer                24
# Civil Engineer               24
# Advocate                     20
# Name: Category, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

category_counts = df["Category"].value_counts()

plt.figure(figsize=(15, 6))
sns.countplot(data=df, x="Category", order=category_counts.index)
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Count")
plt.title("Count of Categories")
plt.show()

# %%
df["Resume"] = df["Resume"].str.lower()
import re
# Removing HTML tags if Resume is Bulit on Webpage
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'',text)

df["Resume"] =df['Resume'].apply(remove_html_tags)

# %%
# If It contains urls etc

def remove_urls(text):
    pattern = re.compile(r'\b(?:https?|ftp)://[^\s/$.?#].[^\s]*\b')
    return pattern.sub(r'',text)

df["Resume"] =df['Resume'].apply(remove_urls)

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))

def remove_stopwords_and_special_chars(text):
    # Remove special characters using regex
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)

    # Split the text into words
    words = text.split()

    # Remove stopwords and fill with spaces
    filtered_words = [word if word not in stop_words else " " for word in words]

    filtered_text = " ".join(filtered_words)

    return filtered_text

# Apply the function to the "Resume" column in your DataFrame
df["Resume"] = df["Resume"].apply(remove_stopwords_and_special_chars)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nihal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk.download('punkt')
from nltk.tokenize import word_tokenize
tokens = df["Resume"].apply(word_tokenize)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nihal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
skills_list = [
    "Python",
    "Java",
    "JavaScript",
    "C++",
    "SQL",
    "Data Analysis",
    "Machine learning",
    "Deep Learning",
    "Artificial Intelligence (AI)",
    "Natural Language Processing (NLP)",
    "Data Mining",
    "Data Visualization",
    "Statistical Analysis",
    "Cloud Computing (e.g., AWS, Azure)",
    "DevOps",
    "Docker",
    "Kubernetes",
    "Web Development",
    "Mobile App Development",
    "Front-End Development",
    "Back-End Development",
    "Full-Stack Development",
    "Agile Methodology",
    "Scrum",
    "Project Management",
    "Leadership",
    "Teamwork",
    "Communication",
    "Problem Solving",
    "Critical Thinking",
    "Creativity",
    "UX/UI Design",
    "Cybersecurity",
    "Network Administration",
    "Database Management",
    "Big Data",
    "Internet of Things (IoT)",
    "Blockchain",
     "Robotics",
    "Automation",
    "Quality Assurance (QA)",
    "Technical Support",
    "Sales",
    "Marketing",
    "Content Writing",
    "Graphic Design",
    "Customer Service",
    "Financial Analysis",
    "Legal Knowledge",
    "Healthcare Management",
    "Pandas",
    "Numpy",
    "Matplotlib",
    "Seaborn",
    "Sklearn",
    "Algorithms",
    "github",
    "django",
]

# %%
import nltk

extracted_skills_per_resume = []

for resume_text in df["Resume"]:
    # Tokenize the resume text using NLTK
    tokens = nltk.word_tokenize(resume_text)

    # Extract skills that exist in the skills_list and are present in the resume
    skills = [skill.lower() for skill in skills_list if skill.lower() in [token.lower() for token in tokens]]

    extracted_skills_per_resume.append(skills)

# Add the extracted skills to your DataFrame
df["Extracted_Skills"] = extracted_skills_per_resume

# %%
df
# Out:
#          Category                                             Resume  \
# 0    Data Science  skills programming languages python pandas num...
# 1    Data Science  education details may 2013   may 2017   uitrgp...
# 2    Data Science  areas   interest deep learning control system ...
# 3    Data Science  skills r python sap hana tableau sap hana sql ...
# 4    Data Science  education details mca ymcaust faridabad haryan...
# ..            ...                                                ...
# 957       Testing  computer skills proficient   ms office word ba...
# 958       Testing  willingness   accept   challenges positive thi...
# 959       Testing  personal skills quick learner eagerness   lear...
# 960       Testing  computer skills software knowledge mspower poi...
# 961       Testing  skill set os windows xp788110 database mysql s...
#
#                                       Extracted_Skills
# 0    [python, java, javascript, sql, docker, pandas...
# 1                                    [python, sklearn]
# 2               [python, java, sql, marketing, github]
# 3    [python, sql, communication, marketing, algori...
# 4                                       [python, java]
# ..                                                 ...
# 957                                       [creativity]
# 958                                                 []
# 959                                       [leadership]
# 960                                                 []
# 961                            [java, sql, automation]
#
# [962 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Category"] =  le.fit_transform(df["Category"])

# %%
print(len(df["Category"].unique()))
print(df["Category"].unique())
# Out:
# 25
# [ 6 12  0  1 24 16 22 14  5 15  4 21  2 11 18 20  8 17 19  7 13 10  9  3
#  23]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
BOW = cv.fit_transform(df["Resume"])
BOW
# Out:
# <962x7994 sparse matrix of type '<class 'numpy.int64'>'
# 	with 169514 stored elements in Compressed Sparse Row format>

# %%
BOW.shape
# Out:
# (962, 7994)

# %%
cv.vocabulary_
# Out:
# {'skills': 6615,
#  'programming': 5615,
#  'languages': 4069,
#  'python': 5740,
#  'pandas': 5162,
#  'numpy': 4920,
#  'scipy': 6359,
#  'scikitlearn': 6357,
#  'matplotlib': 4458,
#  'sql': 6776,
#  'java': 3878,
#  'javascriptjquery': 3884,
#  'machine': 4303,
#  'learning': 4123,
#  'regression': 5960,
#  'svm': 7005,
#  'nave': 4792,
#  'bayes': 1012,
#  'knn': 4008,
#  'random': 5826,
#  'forest': 3011,
#  'decision': 2088,
#  'trees': 7394,
#  'boosting': 1145,
#  'techniques': 7131,
#  'cluster': 1523,
#  'analysis': 647,
#  'word': 7885,
#  'embedding': 2534,
#  'sentiment': 6462,
#  'natural': 4788,
#  'language': 4068,
#  'processing': 5572,
#  'dimensionality': 2272,
#  'reduction': 5931,
#  'topic': 7305,
#  'modelling': 4635,
#  'lda': 4103,
#  'nmf': 4869,
#  'pca': 5246,
#  'neural': 4841,
#  'nets': 4833,
#  'database': 2021,
#  'visualizations': 7726,
#  'mysql': 4758,
#  'sqlserver': 6787,
#  'cassandra': 1330,
#  'hbase': 3347,
#  'elasticsearch': 2506,
#  'd3js': 1999,
#  'dcjs': 2059,
#  'plotly': 5385,
#  'kibana': 3994,
#  'ggplot': 3178,
#  'tableau': 7046,
#  'others': 5092,
#  'regular': 5961,
#  'expression': 2787,
#  'html': 3486,
#  'css': 1946,
#  'angular': 667,
#  'logstash': 4260,
#  'kafka': 3958,
#  'flask': 2962,
#  'git': 3188,
#  'docker': 2347,
#  'computer': 1671,
#  'vision': 7713,
#  'open': 5009,
#  'cv': 1987,
#  'understanding': 7505,
#  'deep': 2103,
#  'learningeducation': 4125,
#  'details': 2200,
#  'data': 2019,
#  'science': 6351,
#  'assurance': 841,
#  'associate': 835,
#  'ernst': 2645,
#  'young': 7981,
#  'llp': 4220,
#  'skill': 6611,
#  'javascript': 3883,
#  'exprience': 2789,
#  '24': 168,
#  'months': 4671,
#  'jquery': 3928,
#  'monthscompany': 4672,
#  'company': 1621,
#  'description': 2175,
#  'fraud': 3052,
#  'investigations': 3803,
#  'dispute': 2318,
#  'services': 6486,
#  'technology': 7140,
#  'assisted': 831,
#  'review': 6116,
#  'tar': 7084,
#  'assists': 834,
#  'accelerating': 375,
#  'process': 5567,
#  'run': 6235,
#  'analytics': 653,
#  'generate': 3157,
#  'reports': 6020,
#  'core': 1829,
#  'member': 4514,
#  'team': 7118,
#  'helped': 3374,
#  'developing': 2219,
#  'automated': 901,
#  'platform': 5372,
#  'tool': 7300,
#  'scratch': 6370,
#  'assisting': 833,
#  'discovery': 2298,
#  'domain': 2360,
#  'implements': 3576,
#  'predictive': 5486,
#  'coding': 1547,
#  'automating': 904,
#  'reviews': 6120,
#  'resulting': 6091,
#  'reduced': 5929,
#  'labor': 4048,
#  'costs': 1855,
#  'time': 7259,
#  'spent': 6752,
#  'lawyers': 4095,
#  'understand': 7504,
#  'end': 2559,
#  'flow': 2975,
#  'solution': 6692,
#  'research': 6043,
#  'development': 2220,
#  'classification': 1489,
#  'models': 4636,
#  'mining': 4599,
#  'information': 3659,
#  'present': 5513,
#  'text': 7192,
#  'worked': 7890,
#  'analyzing': 658,
#  'outputs': 5106,
#  'precision': 5480,
#  'monitoring': 4663,
#  'entire': 2609,
#  'evidence': 2705,
#  'following': 2995,
#  'ey': 2811,
#  'standards': 6829,
#  'developed': 2212,
#  'classifier': 1491,
#  'order': 5053,
#  'identify': 3526,
#  'red': 5923,
#  'flags': 2959,
#  'fraudrelated': 3053,
#  'issues': 3849,
#  'tools': 7301,
#  'technologies': 7137,
#  'tfidf': 7196,
#  'word2vec': 7886,
#  'doc2vec': 2346,
#  'cosine': 1849,
#  'similarity': 6578,
#  'vader': 7603,
#  'blob': 1107,
#  'matplot': 4457,
#  'lib': 4163,
#  'dashboard': 2017,
#  'reporting': 6019,
#  'multiple': 4728,
#  'analytic': 650,
#  'projects': 5631,
#  'usa': 7561,
#  'clients': 1503,
#  'motor': 4686,
#  'vehicle': 7644,
#  'customer': 1974,
#  'received': 5894,
#  'feedback': 2884,
#  'survey': 6999,
#  'past': 5217,
#  'one': 4989,
#  'year': 7969,
#  'performed': 5268,
#  'positive': 5430,
#  'negative': 4812,
#  'neutral': 4843,
#  'series': 6474,
#  'comments': 1593,
#  'across': 429,
#  'categories': 1336,
#  'created': 1898,
#  'heat': 3367,
#  'map': 4404,
#  'terms': 7177,
#  'category': 1338,
#  'based': 999,
#  'frequency': 3064,
#  'words': 7887,
#  'extracted': 2803,
#  'plotted': 5387,
#  'cloud': 1517,
#  'customized': 1982,
#  'dashboards': 2018,
#  'effective': 2485,
#  'chatbot': 1417,
#  'user': 7568,
#  'friendly': 3069,
#  'products': 5588,
#  'handle': 3319,
#  'simple': 6579,
#  'questions': 5778,
#  'hours': 3465,
#  'operation': 5021,
#  'reservation': 6046,
#  'options': 5043,
#  'chat': 1416,
#  'bot': 1149,
#  'serves': 6482,
#  'product': 5582,
#  'related': 5973,
#  'giving': 3196,
#  'overview': 5122,
#  'via': 7673,
#  'qa': 5745,
#  'also': 605,
#  'give': 3193,
#  'recommendation': 5905,
#  'responses': 6072,
#  'question': 5776,
#  'build': 1224,
#  'chain': 1389,
#  'relevant': 5986,
#  'answer': 683,
#  'intelligence': 3739,
#  'pipeline': 5339,
#  'per': 5262,
#  'requirement': 6038,
#  'asks': 802,
#  'recommended': 5907,
#  'nltk': 4867,
#  'spacy': 6725,
#  'governance': 3239,
#  'organizations': 5066,
#  'make': 4351,
#  'informed': 3660,
#  'decisions': 2089,
#  'store': 6874,
#  'integrated': 3733,
#  'portfolio': 5425,
#  'synthesizes': 7035,
#  'unstructured': 7530,
#  'sources': 6716,
#  'facilitates': 2826,
#  'action': 432,
#  'ensure': 2595,
#  'best': 1050,
#  'positioned': 5429,
#  'counter': 1864,
#  'risk': 6151,
#  'scan': 6317,
#  'formats': 3017,
#  'parse': 5185,
#  'different': 2260,
#  'file': 2903,
#  'extract': 2802,
#  'meta': 4538,
#  'push': 5729,
#  'results': 6093,
#  'indexing': 3626,
#  'elastic': 2505,
#  'search': 6395,
#  'interactive': 3751,
#  'using': 7575,
#  'preforming': 5492,
#  'rot': 6190,
#  'helps': 3376,
#  'content': 1761,
#  'either': 2502,
#  'redundant': 5932,
#  'outdated': 5098,
#  'trivial': 7415,
#  'fulltext': 3091,
#  'predefined': 5482,
#  'methods': 4548,
#  'tag': 7054,
#  'pii': 5332,
#  'personally': 5286,
#  'identifiable': 3522,
#  'social': 6668,
#  'security': 6415,
#  'numbers': 4917,
#  'addresses': 466,
#  'names': 4774,
#  'etc': 2680,
#  'frequently': 3066,
#  'targeted': 7086,
#  'cyberattacks': 1994,
#  'investigative': 3804,
#  'flag': 2957,
#  'cases': 1325,
#  'fap': 2859,
#  'inbuilt': 3597,
#  'case': 1324,
#  'manager': 4372,
#  'suite': 6958,
#  'various': 7627,
#  'erp': 2646,
#  'systems': 7041,
#  'used': 7566,
#  'interrogate': 3777,
#  'accounting': 408,
#  'identifying': 3527,
#  'anomalies': 678,
#  'indicators': 3632,
#  'running': 6237,
#  'advanced': 496,
#  'bootstrap': 1147,
#  'nodejs': 4873,
#  'education': 2479,
#  'may': 4472,
#  '2013': 134,
#  '2017': 146,
#  'uitrgpv': 7488,
#  'scientist': 6355,
#  'matelabs': 4448,
#  'less': 4146,
#  'statsmodels': 6853,
#  '12': 38,
#  'aws': 932,
#  'sklearn': 6618,
#  'keras': 3984,
#  'ml': 4617,
#  'business': 1238,
#  'professionals': 5595,
#  'dummies': 2423,
#  'enthusiasts': 2608,
#  '60a': 289,
#  'koramangala': 4022,
#  '5th': 286,
#  'block': 1108,
#  'achievementstasks': 419,
#  'behind': 1038,
#  'sukh': 6961,
#  'sagar': 6253,
#  'bengaluru': 1046,
#  'india': 3627,
#  'deployed': 2159,
#  'auto': 897,
#  'preprocessing': 5506,
#  'steps': 6865,
#  'mainly': 4337,
#  'missing': 4609,
#  'value': 7612,
#  'treatment': 7392,
#  'outlier': 5102,
#  'detection': 2203,
#  'encoding': 2555,
#  'scaling': 6315,
#  'feature': 2878,
#  'selection': 6428,
#  'model': 4632,
#  'linkedincominadityarathore': 4192,
#  'b4600b146': 947,
#  'reasearch': 5879,
#  'forecasting': 3006,
#  'arima': 763,
#  'sarimax': 6282,
#  'holtwinter': 3440,
#  'prophet': 5652,
#  'metafeature': 4541,
#  'extracting': 2804,
#  'problem': 5562,
#  'githubcomrathorology': 3192,
#  'implemented': 3574,
#  'state': 6842,
#  'art': 779,
#  'paper': 5168,
#  'mixed': 4615,
#  'attributes': 872,
#  'areas': 758,
#  'interest': 3754,
#  'control': 1787,
#  'system': 7037,
#  'design': 2177,
#  'inpython': 3693,
#  'electric': 2509,
#  'machinery': 4304,
#  'web': 7807,
#  'technical': 7125,
#  'activities': 440,
#  'hindustan': 3407,
#  'aeronautics': 514,
#  'limited': 4182,
#  'bangalore': 977,
#  'weeks': 7826,
#  'guidance': 3287,
#  'mr': 4702,
#  'satish': 6294,
#  'senior': 6452,
#  'engineer': 2574,
#  'hangar': 3331,
#  'mirage': 4605,
#  '2000': 95,
#  'fighter': 2900,
#  'aircraft': 552,
#  'matlab': 4456,
#  'labview': 4054,
#  'webframeworkdjango': 7810,
#  'ltspiceintermediate': 4294,
#  'mipowerintermediate': 4604,
#  'github': 3191,
#  'gitbash': 3189,
#  'jupyter': 3955,
#  'notebook': 4896,
#  'xampp': 7941,
#  'mysqlbasics': 4760,
#  'software': 6677,
#  'packages': 5140,
#  'interpretersanaconda': 3776,
#  'python2': 5741,
#  'python3': 5742,
#  'pycharm': 5737,
#  'ideeclipse': 3521,
#  'operating': 5019,
#  'windows': 7859,
#  'ubuntu': 7473,
#  'debiankali': 2077,
#  'linux': 4195,
#  'january': 3873,
#  '2019': 151,
#  'btech': 1211,
#  'electrical': 2510,
#  'electronics': 2514,
#  'engineering': 2577,
#  'manipal': 4387,
#  'institute': 3716,
#  '2015': 138,
#  'deeksha': 2102,
#  'center': 1365,
#  'little': 4214,
#  'flower': 2976,
#  'public': 5699,
#  'school': 6345,
#  'august': 883,
#  'academy': 372,
#  'higher': 3390,
#  'enthusiast': 2606,
#  'excel': 2718,
#  'mathematics': 4454,
#  'themathcompany': 7218,
#  'currently': 1966,
#  'working': 7898,
#  'casino': 1329,
#  'operatorname': 5026,
#  'disclosed': 2293,
#  'macaui': 4302,
#  'need': 4809,
#  'segment': 6420,
#  'customers': 1975,
#  'visit': 7714,
#  'property': 5651,
#  'patrons': 5232,
#  'bring': 1187,
#  'companybasically': 1622,
#  'prove': 5673,
#  'segmentation': 6421,
#  'done': 2364,
#  'much': 4715,
#  'better': 1051,
#  'way': 7798,
#  'current': 1965,
#  'proper': 5648,
#  'back': 951,
#  'uphenceforth': 7547,
#  'implement': 3571,
#  'target': 7085,
#  'marketing': 4421,
#  'strategy': 6888,
#  'attract': 868,
#  'add': 454,
#  'sap': 6277,
#  'hana': 3315,
#  'pal': 5156,
#  'ms': 4705,
#  'lumira': 4296,
#  'linear': 4186,
#  'advance': 495,
#  'scm': 6360,
#  'retail': 6096,
#  'media': 4498,
#  'nlp': 4866,
#  '2018': 149,
#  'pgdm': 5300,
#  'great': 3260,
#  'lakes': 4058,
#  'management': 4365,
#  'illinois': 3556,
#  'bachelor': 949,
#  'communication': 1612,
#  'karnataka': 3970,
#  'new': 4844,
#  'horizon': 3452,
#  'college': 1572,
#  'visvesvaraya': 7729,
#  'technological': 7136,
#  'university': 7525,
#  'consultant': 1746,
#  'deloitte': 2138,
#  'usi': 7574,
#  'project': 5624,
#  'involved': 3816,
#  'analysing': 646,
#  'historic': 3415,
#  'deals': 2074,
#  'coming': 1588,
#  'insights': 3703,
#  'optimize': 5038,
#  'future': 3109,
#  'role': 6174,
#  'given': 3194,
#  'raw': 5846,
#  'carried': 1316,
#  'presented': 5516,
#  'client': 1501,
#  'key': 3986,
#  'responsibilities': 6073,
#  'geographies': 3170,
#  'infer': 3649,
#  'meaningful': 4484,
#  'prices': 5536,
#  'find': 2925,
#  'blockades': 1109,
#  'environment': 2619,
#  'industry': 3644,
#  'cross': 1929,
#  'service': 6483,
#  'area': 756,
#  'name': 4773,
#  'handwriting': 3328,
#  'recognition': 5899,
#  'taking': 7068,
#  'handwritten': 3329,
#  'images': 3560,
#  'converting': 1804,
#  'digital': 2265,
#  'object': 4932,
#  'sentence': 6461,
#  'creation': 1903,
#  'correction': 1841,
#  'functionality': 3097,
#  'gather': 3138,
#  'large': 4075,
#  'enough': 2588,
#  'capture': 1302,
#  'english': 2580,
#  'train': 7348,
#  'lstm': 4289,
#  'finance': 2919,
#  'financial': 2921,
#  'bi': 1067,
#  'swift': 7013,
#  'develop': 2211,
#  'infrastructure': 3667,
#  'top': 7304,
#  's4': 6243,
#  'would': 7909,
#  'view': 7692,
#  'respective': 6065,
#  'departments': 2152,
#  'included': 3605,
#  'expenses': 2759,
#  'leading': 4111,
#  'offshore': 4965,
#  'etl': 2689,
#  'validate': 7605,
#  'ao': 691,
#  'healthcare': 3361,
#  'life': 4170,
#  'sciences': 6352,
#  'clinical': 1504,
#  'argus': 760,
#  'allow': 597,
#  'users': 7571,
#  'query': 5772,
#  'faster': 2867,
#  'provide': 5675,
#  'capabilities': 1293,
#  'deploy': 2158,
#  'phase': 5306,
#  'lot': 4279,
#  'restructuring': 6089,
#  'built': 1232,
#  'analytical': 652,
#  'fmcg': 2985,
#  'trade': 7342,
#  'promotion': 5642,
#  'consumption': 1753,
#  'planning': 5361,
#  'flowers': 2977,
#  'foods': 3000,
#  'setting': 6499,
#  'crm': 1924,
#  'cbp': 1347,
#  'modules': 4651,
#  'decomposition': 2094,
#  'base': 998,
#  'forecast': 3005,
#  'course': 1873,
#  'performance': 5266,
#  'improvements': 3592,
#  'views': 7695,
#  'customersalesfunds': 1976,
#  'bobj': 1129,
#  'internal': 3764,
#  'initiative': 3674,
#  'rfm': 6132,
#  'hanapython': 3316,
#  'interface': 3756,
#  'successfully': 6942,
#  'segmented': 6422,
#  'five': 2950,
#  'segments': 6423,
#  'kmeans': 4007,
#  'algorithm': 580,
#  'categorize': 1337,
#  'defined': 2113,
#  'buckets': 1215,
#  'anaconda3': 641,
#  'python36': 5743,
#  'sps12': 6773,
#  'telecom': 7147,
#  'invoice': 3810,
#  'reduce': 5928,
#  'manual': 4395,
#  'effort': 2492,
#  'verifying': 7656,
#  'closed': 1512,
#  'invoices': 3812,
#  'manually': 4397,
#  'tree': 7393,
#  'classify': 1492,
#  'openclosed': 5011,
#  'enabled': 2551,
#  '60': 287,
#  'accenture': 378,
#  'experience': 2761,
#  'developer': 2214,
#  '19': 69,
#  'solutions': 6694,
#  'pvt': 5733,
#  'ltd': 4291,
#  'ipa': 3826,
#  'objects': 4935,
#  'operational': 5022,
#  'kpis': 4025,
#  'spearheaded': 6735,
#  'deployments': 2162,
#  'introduced': 3793,
#  'reuse': 6112,
#  'functionalities': 3096,
#  'prepared': 5503,
#  'production': 5583,
#  'designed': 2180,
#  'attribute': 871,
#  'calculation': 1265,
#  'individually': 3636,
#  'complex': 1653,
#  'scripts': 6379,
#  'procedures': 5566,
#  'took': 7299,
#  'ownership': 5126,
#  'building': 1229,
#  'algorithms': 581,
#  'executed': 2732,
#  'server': 6477,
#  'tsql': 7438,
#  'testing': 7184,
#  'accelerator': 376,
#  '21': 157,
#  'taken': 7065,
#  'care': 1310,
#  'atas': 847,
#  'completed': 1650,
#  'apart': 697,
#  'actively': 437,
#  'maintenance': 4345,
#  'servers': 6480,
#  'quality': 5762,
#  'requirements': 6039,
#  'scope': 6363,
#  'getting': 3176,
#  'clarified': 1482,
#  'interacting': 3749,
#  'transform': 7362,
#  'mapping': 4407,
#  'documents': 2355,
#  'reviewing': 6119,
#  'specification': 6745,
#  'documentation': 2351,
#  'create': 1897,
#  'update': 7536,
#  'like': 4178,
#  'tables': 7047,
#  'stored': 6875,
#  'function': 3094,
#  'monitored': 4662,
#  'error': 2648,
#  'logs': 4259,
#  'application': 713,
#  'agent': 523,
#  'diagrams': 2252,
#  'entity': 2611,
#  'relationship': 5980,
#  'uml': 7495,
#  'responsible': 6076,
#  'designing': 2185,
#  'normalization': 4886,
#  'tuning': 7445,
#  'profiler': 5601,
#  'uat': 7470,
#  'knowledge': 4011,
#  'transfer': 7361,
#  'support': 6987,
#  '20082014': 120,
#  'visual': 7723,
#  'studio': 6909,
#  '2010': 126,
#  'monitor': 4661,
#  'plsql': 5389,
#  'mca': 4477,
#  'ymcaust': 7978,
#  'faridabad': 2861,
#  'haryana': 3341,
#  'internship': 3772,
#  'structure': 6902,
#  'itechpower': 3852,
#  'basics': 1003,
#  'iot': 3824,
#  'microsoft': 4569,
#  'powerpoint': 5452,
#  'academic': 371,
#  'secured': 6412,
#  'first': 2944,
#  'place': 5350,
#  'btecheducation': 1212,
#  '2014': 137,
#  'ghatkesar': 3180,
#  'andhra': 661,
#  'pradesh': 5469,
#  'auroras': 885,
#  'scientific': 6354,
#  'june': 3947,
#  '2012': 130,
#  'secondary': 6404,
#  'warangal': 7778,
#  'telangana': 7146,
#  'sr': 6790,
#  'junior': 3950,
#  'office': 4958,
#  'visualization': 7725,
#  'statistics': 6851,
#  'iabac': 3507,
#  'certified': 1384,
#  'versatile': 7658,
#  'years': 7971,
#  'managing': 4381,
#  'consulting': 1749,
#  'innovation': 3683,
#  'bringing': 1188,
#  'ideas': 3520,
#  'real': 5872,
#  'world': 7906,
#  'strong': 6900,
#  'advocator': 509,
#  'augmented': 882,
#  'era': 2641,
#  'human': 3494,
#  'enhanced': 2582,
#  'machines': 4305,
#  'fahed': 2844,
#  'passionate': 5213,
#  'concepts': 1678,
#  'ai': 545,
#  'robotics': 6169,
#  'solutionseducation': 6695,
#  'tech': 7123,
#  'mohali': 4653,
#  'punjab': 5715,
#  'indo': 3638,
#  'global': 3202,
#  'datamites': 2032,
#  '13': 46,
#  'analyzed': 656,
#  'processed': 5569,
#  'sets': 6498,
#  'querying': 5774,
#  'loading': 4230,
#  'validation': 7607,
#  'manipulating': 4388,
#  'cleaning': 1493,
#  'heretic': 3379,
#  'closely': 1513,
#  'propose': 5657,
#  'making': 4354,
#  'cleansing': 1494,
#  'drawing': 2389,
#  'conclusions': 1689,
#  'recommendations': 5906,
#  'statistical': 6850,
#  'produce': 5577,
#  'problems': 5564,
#  'rayat': 5848,
#  'bahra': 962,
#  'biotechnology': 1088,
#  'tensorflow': 7169,
#  'scikit': 6356,
#  'gcp': 3144,
#  'network': 4836,
#  'wipro': 7870,
#  'bhawana': 1063,
#  'aggarwal': 525,
#  'emailbhawanachdgmailcom': 2530,
#  'phone': 5312,
#  '09876971076': 15,
#  'vversatile': 7756,
#  'highenergy': 3389,
#  'professional': 5592,
#  'targeting': 7087,
#  'challenging': 1392,
#  'assignments': 827,
#  'profile': 5600,
#  'summary': 6963,
#  'skilled': 6612,
#  'endtoend': 2564,
#  'inception': 3600,
#  'specs': 6749,
#  'implementation': 3572,
#  'configuration': 1705,
#  'libraries': 4164,
#  'seaborn': 6390,
#  'cufflinks': 1956,
#  'bias': 1069,
#  'variance': 7622,
#  'vector': 7641,
#  'machinesvmlogistic': 4307,
#  'networks': 4839,
#  'unsupervised': 7531,
#  'supervised': 6976,
#  'reinforcement': 5970,
#  'relational': 5977,
#  'platforms': 5373,
#  'mysqloracle': 4761,
#  'cjava': 1473,
#  'google': 3232,
#  'good': 3230,
#  'interpersonal': 3773,
#  'solving': 6698,
#  'ability': 361,
#  'think': 7227,
#  'laterally': 4082,
#  'medium': 4507,
#  'term': 7174,
#  'long': 4264,
#  'perspective': 5288,
#  'flexibility': 2967,
#  'attitude': 865,
#  'change': 1397,
#  'define': 2112,
#  'frameworks': 3047,
#  'emphasis': 2541,
#  'code': 1541,
#  'reusability': 6110,
#  'logistic': 4254,
#  'means': 4485,
#  'clustering': 1524,
#  'databases': 2023,
#  'oracle': 5045,
#  'window': 7858,
#  'environments': 2622,
#  'netbeans': 4826,
#  'notebooks': 4897,
#  'sublime': 6922,
#  'ticketing': 7245,
#  'remedy': 5996,
#  'ug': 7483,
#  'passed': 5210,
#  '784in': 314,
#  '2016': 141,
#  'schooling': 6346,
#  'xii': 7947,
#  'moti': 4680,
#  'ram': 5822,
#  'arya': 787,
#  'schoolpassed': 6347,
#  '784': 313,
#  'valley': 7610,
#  '94': 337,
#  'cgpa': 1387,
#  'work': 7888,
#  'experince': 2764,
#  'title': 7273,
#  'size': 6607,
#  'brief': 1184,
#  'wipros': 7871,
#  'harnesses': 3337,
#  'power': 5449,
#  'automation': 905,
#  'artificial': 784,
#  'technologiesnatural': 7138,
#  'cognitive': 1549,
#  'comprises': 1669,
#  'three': 7233,
#  'layers': 4098,
#  'engagement': 2570,
#  'easily': 2448,
#  'access': 384,
#  'manage': 4362,
#  'structured': 6903,
#  'intent': 3745,
#  'assessment': 819,
#  'reasoning': 5883,
#  'engine': 2573,
#  'includes': 3606,
#  'sense': 6454,
#  'act': 430,
#  'learn': 4119,
#  'entailed': 2599,
#  'queries': 5771,
#  'earliest': 2443,
#  'monster': 4667,
#  'see': 6416,
#  'answered': 684,
#  'quickly': 5783,
#  'alll1': 592,
#  'eliminated': 2525,
#  'extractor': 2806,
#  'involves': 3818,
#  'extraction': 2805,
#  'fetching': 2892,
#  'important': 3580,
#  'dates': 2040,
#  'places': 5352,
#  'contact': 1754,
#  'regex': 5949,
#  'bluemix': 1118,
#  'nlu': 4868,
#  'apis': 703,
#  'tensor': 7168,
#  'entities': 2610,
#  'classifications': 1490,
#  'classes': 1486,
#  'training': 7353,
#  'dataset': 2034,
#  'predicting': 5485,
#  'output': 5105,
#  'mnb': 4625,
#  'sgd': 6510,
#  'optimization': 5037,
#  'suited': 6959,
#  'response': 6071,
#  'efficient': 2489,
#  'ner': 4821,
#  'trained': 7349,
#  'roles': 6175,
#  'rnnlstm': 6163,
#  'bidirectional': 1072,
#  'framework': 3046,
#  'diabetes': 2246,
#  'detect': 2202,
#  'whether': 7840,
#  'person': 5282,
#  'suffering': 6944,
#  'got': 3237,
#  'third': 7230,
#  'prize': 5556,
#  'certifications': 1383,
#  'organization': 5064,
#  'udemy': 7478,
#  'coursera': 1874,
#  'personal': 5283,
#  'fathers': 2870,
#  'tirlok': 7270,
#  'known': 4013,
#  'hindi': 3405,
#  'marital': 4419,
#  'status': 6854,
#  'single': 6591,
#  'date': 2038,
#  'birthgender19931220yyyymmdd': 1093,
#  'programs': 5618,
#  'grasp': 3256,
#  'aspects': 808,
#  'willingness': 7852,
#  'high': 3388,
#  'energy': 2568,
#  'levels': 4152,
#  ...}

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y , test_y  = train_test_split(BOW,df["Category"] ,test_size=0.2, random_state=41)

# %%
train_x.shape
# Out:
# (769, 7994)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=41, n_estimators=50)
rf.fit(train_x, train_y)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=41)

# %%
ypred = rf.predict(test_x)

# %%
from sklearn.metrics import accuracy_score
accuracy_score = accuracy_score(test_y, ypred)
print(accuracy_score)
# Out:
# 0.9896373056994818

# %%
from pypdf import PdfReader

# %%
reader = PdfReader('SALVA_FATHIMA_RESUME_2023_ (1) (1).pdf')

# %%
print(len(reader.pages))
# Out:
# 2

# %%
page = reader.pages[0]
text = page.extract_text()
print(text)
# Out:
# S a l v a
# F a t h i m a
# S
# P a t t a t h a r a
# h o u s e ,
# V a l a n j a v a z h y
# P
# O ,
# A l a p p u z h a ,
# 6 8 8 0 0 5
# Contact
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# 8 1 2 9 4 8 3 2 5 7
# 
# s a l v a f a t h i m a 2 8 @ g m a i l . c o m
# 
# h t t p s : / / w w w . l i n k e d i n . c o m / i n / s a l v a - f a t h i m a - 0 8 8 b 7 a 2 4 5
# E ducation
# _____________________________________________________________________
# Muthoot
# Institute
# of
# T echnology
# and
# Science
# E r n a k u l a m ,
# K e r a l a
# B.TECH
# IN
# AR TIFICI AL
# IN TELLIGENCE
# AND
# D A T ASCIECNE
# A u g u s t
# 2 0 2 1 -
# J u l y
# 2 0 2 5
# PRESEN T
# GP A
# :
# 8.32
# ST
# Joseph ’ s
# Girls
# Higher
# Secondar y
# School
# A l a p p u z h a , K e r a l a
# XII
# ST A TE
# 2 0 1 9 - 2 0 2 1
# PERCEN T A GE
# :
# 94%
# Skills
# __________________________________________________________________________
# Languages
# :
# P ython,C,,H TML,CSS,Ja v a.
# Databases
# :
# MySQL,MongodB.
# F amiliar
# Ar eas
# :
# F r ontend
# De v elopment,
# Flask,
# Machine
# Learning,
# Data
# Structur es
# &
# Algorithms,
# Data
# Science,
# Ar tiﬁcial
# Intelligence.
# Soft
# Skills
# :
# Leadership
# ,
# Good
# Communication,Quick
# Learner ,Multitasking,P assionate,Self-driv en,
# Highly-focused.
# Internship
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# K er ala
# State
# Electr onics
# De v elopment
# Corpor ation
# Ltd.
# (KEL TRON)
# T h i r u v a n a n t h a p u r a m ,
# K e r a l a
# IN TERN
# M a y
# 2 0 2 2
# Studied
# P ython
# Basics,
# P ython
# Libr aries,
# Intr oduction
# t o
# Machine
# Learning,
# T ypes
# of
# Machine
# Learning,
# Algorithms
# in
# Machine
# Learning.
# GDC
# FieldOps
# F ellowship
# T h i r u v a n a n t h a p u r a m ,
# K e r a l a
# T r aining
# Pr ogr am
# 2 0 2 2
# Co v er ed
# courses
# on
# how
# go v ernment
# systems
# work
# during
# emer gencies
# and
# exposur e
# in
# using
# Cor onaSaf e
# Network.

# %%
import pickle
pickle.dump(cv,open('cv.pkl','wb'))
pickle.dump(rf, open('clf.pkl', 'wb'))

# %%
import pickle
import re

clf = pickle.load(open('clf.pkl', 'rb'))
cv = pickle.load(open('cv.pkl', 'rb'))


def cleanResume(txt):
    cleanText = re.sub('http\S+\s', ' ', txt)
    cleanText = re.sub('RT|cc', ' ', cleanText)
    cleanText = re.sub('#\S+\s', ' ', cleanText)
    cleanText = re.sub('@\S+', '  ', cleanText)
    cleanText = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', cleanText)
    cleanText = re.sub(r'[^\x00-\x7f]', ' ', cleanText)
    cleanText = re.sub('\s+', ' ', cleanText)
    return cleanText

def extract_skills_from_resume(resume_text, skills_list):
    # Tokenize the resume text using NLTK
    tokens = nltk.word_tokenize(resume_text, language="english", preserve_line= "False")
    # Extract skills that exist in the skills_list and are present in the resume
    skills = [skill.lower() for skill in skills_list if skill.lower() in [token.lower() for token in tokens]]
    return skills



cleaned_resume = cleanResume(text)

skills = extract_skills_from_resume(text, skills_list)

input_features = cv.transform([cleaned_resume])

prediction_id = clf.predict(input_features)[0]

category_mapping = {
    15: "Java Developer",
    23: "Testing",
    8: "DevOps Engineer",
    20: "Python Developer",
    24: "Web Designing",
    12: "HR",
    13: "Hadoop",
    3: "Blockchain",
    10: "ETL Developer",
    18: "Operations Manager",
    6: "Data Science",
    22: "Sales",
    16: "Mechanical Engineer",
    1: "Arts",
    7: "Database",
    11: "Electrical Engineering",
    14: "Health and fitness",
    19: "PMO",
    4: "Business Analyst",
    9: "DotNet Developer",
    2: "Automation Testing",
    17: "Network Security Engineer",
    21: "SAP Developer",
    5: "Civil Engineer",
    0: "Advocate",
}

category_name = category_mapping.get(prediction_id, "Unknown")

print("Predicted Category:", category_name)
print(prediction_id)
print(skills)
# Out:
# Predicted Category: HR
# 12
# ['leadership', 'communication', 'algorithms']

# %%
 tokens = nltk.word_tokenize(cleaned_resume)

# %%
print(tokens)
# Out:
# ['S', 'a', 'l', 'v', 'a', 'F', 'a', 't', 'h', 'i', 'm', 'a', 'S', 'P', 'a', 't', 't', 'a', 't', 'h', 'a', 'r', 'a', 'h', 'o', 'u', 's', 'e', 'V', 'a', 'l', 'a', 'n', 'j', 'a', 'v', 'a', 'z', 'h', 'y', 'P', 'O', 'A', 'l', 'a', 'p', 'p', 'u', 'z', 'h', 'a', '6', '8', '8', '0', '0', '5', 'Contact', '8', '1', '2', '9', '4', '8', '3', '2', '5', '7', 's', 'a', 'l', 'v', 'a', 'f', 'a', 't', 'h', 'i', 'm', 'a', '2', '8', 'g', 'm', 'a', 'i', 'l', 'c', 'o', 'm', 'h', 't', 't', 'p', 's', 'w', 'w', 'w', 'l', 'i', 'n', 'k', 'e', 'd', 'i', 'n', 'c', 'o', 'm', 'i', 'n', 's', 'a', 'l', 'v', 'a', 'f', 'a', 't', 'h', 'i', 'm', 'a', '0', '8', '8', 'b', '7', 'a', '2', '4', '5', 'E', 'ducation', 'Muthoot', 'Institute', 'of', 'T', 'echnology', 'and', 'Science', 'E', 'r', 'n', 'a', 'k', 'u', 'l', 'a', 'm', 'K', 'e', 'r', 'a', 'l', 'a', 'B', 'TECH', 'IN', 'AR', 'TIFICI', 'AL', 'IN', 'TELLIGENCE', 'AND', 'D', 'A', 'T', 'ASCIECNE', 'A', 'u', 'g', 'u', 's', 't', '2', '0', '2', '1', 'J', 'u', 'l', 'y', '2', '0', '2', '5', 'PRESEN', 'T', 'GP', 'A', '8', '32', 'ST', 'Joseph', 's', 'Girls', 'Higher', 'Secondar', 'y', 'School', 'A', 'l', 'a', 'p', 'p', 'u', 'z', 'h', 'a', 'K', 'e', 'r', 'a', 'l', 'a', 'XII', 'ST', 'A', 'TE', '2', '0', '1', '9', '2', '0', '2', '1', 'PERCEN', 'T', 'A', 'GE', '94', 'Skills', 'Languages', 'P', 'ython', 'C', 'H', 'TML', 'CSS', 'Ja', 'v', 'a', 'Databases', 'MySQL', 'MongodB', 'F', 'amiliar', 'Ar', 'eas', 'F', 'r', 'ontend', 'De', 'v', 'elopment', 'Flask', 'Machine', 'Learning', 'Data', 'Structur', 'es', 'Algorithms', 'Data', 'Science', 'Ar', 'ti', 'cial', 'Intelligence', 'Soft', 'Skills', 'Leadership', 'Good', 'Communication', 'Quick', 'Learner', 'Multitasking', 'P', 'assionate', 'Self', 'driv', 'en', 'Highly', 'focused', 'Internship', 'K', 'er', 'ala', 'State', 'Electr', 'onics', 'De', 'v', 'elopment', 'Corpor', 'ation', 'Ltd', 'KEL', 'TRON', 'T', 'h', 'i', 'r', 'u', 'v', 'a', 'n', 'a', 'n', 't', 'h', 'a', 'p', 'u', 'r', 'a', 'm', 'K', 'e', 'r', 'a', 'l', 'a', 'IN', 'TERN', 'M', 'a', 'y', '2', '0', '2', '2', 'Studied', 'P', 'ython', 'Basics', 'P', 'ython', 'Libr', 'aries', 'Intr', 'oduction', 't', 'o', 'Machine', 'Learning', 'T', 'ypes', 'of', 'Machine', 'Learning', 'Algorithms', 'in', 'Machine', 'Learning', 'GDC', 'FieldOps', 'F', 'ellowship', 'T', 'h', 'i', 'r', 'u', 'v', 'a', 'n', 'a', 'n', 't', 'h', 'a', 'p', 'u', 'r', 'a', 'm', 'K', 'e', 'r', 'a', 'l', 'a', 'T', 'r', 'aining', 'Pr', 'ogr', 'am', '2', '0', '2', '2', 'Co', 'v', 'er', 'ed', 'courses', 'on', 'how', 'go', 'v', 'ernment', 'systems', 'work', 'during', 'emer', 'gencies', 'and', 'exposur', 'e', 'in', 'using', 'Cor', 'onaSaf', 'e', 'Network']

# %%
 skills = [skill.lower() for skill in skills_list if skill.lower() in [token.lower() for token in tokens]]

# %%
print(skills)
# Out:
# ['leadership', 'communication', 'algorithms']

# %%
multiple_word_skills = [
    "Data Analysis",
    "Machine Learning",
    "Deep Learning",
    "Artificial Intelligence (AI)",
    "Natural Language Processing (NLP)",
    "Data Mining",
    "Data Visualization",
    "Statistical Analysis",
    "Cloud Computing (e.g., AWS, Azure)",
    "Web Development",
    "Mobile App Development",
    "Front-End Development",
    "Back-End Development",
    "Full-Stack Development",
    "Agile Methodology",
    "Quality Assurance (QA)",
    "Internet of Things (IoT)",
    "Customer Service",
    "Financial Analysis",
    "Healthcare Management",
    "Technical Support",
    "Legal Knowledge",
    "Network Administration",
    "UX/UI Design",
    "Graphic Design",
    "Data  Science",
    "Data Structures",
    "problem solving",
]


# Initialize an empty list for skills
skills_list = skills

# Iterate through the multiple-word skills list
for skill in multiple_word_skills:
    # Check if the skill exists in the tokens and if it is adjacent
    if ' '.join(skill.split()) in ' '.join(tokens):
        # Add the skill to the skills list
        skills_list.append(skill)

# Print the updated skills list
print("Skills List with Multiple-Word Skills:", skills_list)
# Out:
# Skills List with Multiple-Word Skills: ['leadership', 'communication', 'algorithms', 'Machine Learning', 'Data  Science']

# %%
skills_list_no_duplicates = list(set(skills_list))

# Print the list without duplicates
print("List without duplicates:", skills_list_no_duplicates)
# Out:
# List without duplicates: ['Data  Science', 'Machine Learning', 'leadership', 'communication', 'algorithms']

# %%
final_skill_list=skills_list_no_duplicates
print(final_skill_list)
# Out:
# ['Data  Science', 'Machine Learning', 'leadership', 'communication', 'algorithms']
